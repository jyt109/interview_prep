# %% [markdown]
# ##Statistics
#
# 1. **Explain what a p-value is ?**
#
#    - How **unlikely** it is to observe **a value as or more extreme that X given the null hypothesis is correct**
#    - **If the mean of population is 7:**
#      - Probability of observing 10000 or more is small
#      - Probability of observing 8 or more is much higher
#
#    <br>
#
# 2. **How would you prove if a coin is unfair ?**
#
#    - Let $X$ be the number of heads when flip 1000 times
#      $$X \sim Binomial(n=1000, p=0.5)$$
#    - The mean is $1000(0.5) = 500$
#    - The standard deviation is $\sqrt{1000(0.5)(0.5)} = \sqrt{250}$
#
#      <br>
#
#    - **By CLT:**
#      $$X \sim Normal(\mu=500, \sigma=\sqrt{250})$$
#
#      <br>
#
#    - **Flipped coin 1000 times and got head $H$ number of times**
#    - **Compute Z-score for $H$:**
#      $$Z = \frac{H - 500}{\sqrt{250}}$$
#
#      <br>
#
#    - **Compute p-value of observing $H$:**
#      $$p = 1 - cdf(Z)$$
#
#      <br>
#
#      If $p < 0.05 /2$ (two-tailed), then null ($\mu$=500) is rejected and coin is unfair
#
#    <br>
#
# 3. **What is a confidence interval and what does it represents ?**
#
#    -
#
#    <br>
#
# 4. **Assume you know the distribution of some dataset, describe the 2 ways to decide the parameters for the distribution that best fit the dataset ?**
#
#    <br>
#
# 5. Describe the central limit theorem. As a data scientist, state a few scenarios where you cannot use the CLT.
#
#    <br>
#
# 6. Describe what is statistical power. Illustrate the concept with an example.
#
#    <br>
#
# 7. What is the difference of using the mean vs the median as a centrality measure ?
#
#    <br>
#
# 8.
#
#
# 3. How do you decide when to stop an experiment ?
#
# 4. Descirbe how you would conduct Bayesian hypothesis testing.
#
# 5. Linear regression  r^2
#
# 6. Variance inflation factor for multicollinearity
